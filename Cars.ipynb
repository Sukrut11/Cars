# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
car=pd.read_csv("C:\\Users\\user\\car_sales.csv")

# %%
car.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
for col in car.columns:
    print (col)
# Out:
# Unnamed: 0
# Manufacturer
# Model
# Type
# Min.Price
# Price
# Max.Price
# MPG.city
# MPG.highway
# AirBags
# DriveTrain
# Cylinders
# EngineSize
# Horsepower
# RPM
# Rev.per.mile
# Man.trans.avail
# Fuel.tank.capacity
# Passengers
# Length
# Wheelbase
# Width
# Turn.circle
# Rear.seat.room
# Luggage.room
# Weight
# Origin
# Make

# %%
car.shape
# Out:
# (93, 28)

# %%
car["Manufacturer"].value_counts()
# Out:
# Ford             8
# Chevrolet        8
# Dodge            6
# Pontiac          5
# Mazda            5
# Nissan           4
# Volkswagen       4
# Buick            4
# Hyundai          4
# Toyota           4
# Oldsmobile       4
# Subaru           3
# Honda            3
# Cadillac         2
# Lexus            2
# Geo              2
# Mercedes-Benz    2
# Mitsubishi       2
# Lincoln          2
# Acura            2
# Audi             2
# Eagle            2
# Mercury          2
# Chrysler         2
# Volvo            2
# Infiniti         1
# Suzuki           1
# Saab             1
# Plymouth         1
# BMW              1
# Saturn           1
# Chrylser         1
# Name: Manufacturer, dtype: int64

# %%
car["Manufacturer"].value_counts()[0:5]
# Out:
# Ford         8
# Chevrolet    8
# Dodge        6
# Pontiac      5
# Mazda        5
# Name: Manufacturer, dtype: int64

# %%
car["Manufacturer"].value_counts()[0:5].keys()
# Out:
# Index(['Ford', 'Chevrolet', 'Dodge', 'Pontiac', 'Mazda'], dtype='object')

# %%
plt.figure(figsize=(6,6))
plt.bar(list(car["Manufacturer"].value_counts()[0:5].keys()),list(car["Manufacturer"].value_counts()[0:5]),color=["Blue","Red","Orange","Gold","Purple"])
plt.xlabel("Company")
plt.ylabel("No. of cars mannufactured")
plt.show()

# %%
airbags=car[car["AirBags"]=="Driver & Passenger"]

# %%
airbags.head()
# Out:
#     Unnamed: 0 Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 1            2        Acura    Legend  Midsize       29.2   33.9       38.7
# 3            4         Audi       100  Midsize       30.8   37.7       44.6
# 10          11     Cadillac   Seville  Midsize       37.5   40.1       42.7
# 13          14    Chevrolet    Camaro   Sporty       13.4   15.1       16.8
# 19          20     Chrylser  Concorde    Large       18.4   18.4       18.4
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 1         18           25  Driver & Passenger  ...          5    195
# 3         19           26  Driver & Passenger  ...          6    193
# 10        16           25  Driver & Passenger  ...          5    204
# 13        19           28  Driver & Passenger  ...          4    193
# 19        20           28  Driver & Passenger  ...          6    203
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
safety=car[["Model","AirBags"]]

# %%
safety.head()
# Out:
#      Model             AirBags
# 0  Integra                None
# 1   Legend  Driver & Passenger
# 2       90         Driver only
# 3      100  Driver & Passenger
# 4     535i         Driver only

# %%
car_price=car[["Model","Price"]]

# %%
car_price.head(10)
# Out:
#         Model  Price
# 0     Integra   15.9
# 1      Legend   33.9
# 2          90   29.1
# 3         100   37.7
# 4        535i   30.0
# 5     Century   15.7
# 6     LeSabre   20.8
# 7  Roadmaster   23.7
# 8     Riviera   26.3
# 9     DeVille   34.7

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             93 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
car.describe()
# Out:
#        Unnamed: 0  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count   93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean    47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std     26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min      1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%     24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%     47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%     70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max     93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
car["Type"].value_counts()
# Out:
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: Type, dtype: int64

# %%
car["Type"].value_counts().keys()
# Out:
# Index(['Midsize', 'Small', 'Compact', 'Sporty', 'Large', 'Van'], dtype='object')

# %%
plt.figure(figsize=(6,6))
plt.pie(list(car["Type"].value_counts()),labels=list(car["Type"].value_counts().keys()),autopct="%0.1f%%")
plt.show()

# %%
model=car["Model"].value_counts().head().index

# %%
price=car["Price"].value_counts().head().index

# %%
car_subset=car[car["Model"].isin(model)]

# %%
sns.lineplot(x=model,y=price,data=car_subset,linestyle="--",markers=True)
plt.show()

# %%
sns.jointplot(x=model,y=price,data=car_subset)
plt.show()

# %%
sns.jointplot(x="Length",y="Width",data=car,kind='kde')
plt.show()

# %%
sns.scatterplot(x=model,y=price,data=car_subset)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.hist(car["EngineSize"],bins=30,color="gold")
plt.show()

# %%
hp=car["Horsepower"].value_counts().head().keys()

# %%
car.describe()
# Out:
#        Unnamed: 0  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count   93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean    47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std     26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min      1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%     24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%     47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%     70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max     93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
Car=car.drop(["Unnamed: 0","Manufacturer","Model"],axis=1)

# %%
names=list(car.Make)[0:5]

# %%
plt.figure(figsize=(7,7))
plt.bar(names,hp,color="red")
plt.title("HorsePower for top five companies")
plt.xlabel("Car Brands")
plt.ylabel("Hp")
plt.show()

# %%
Car
# Out:
#        Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0     Small       12.9   15.9       18.8        25           31
# 1   Midsize       29.2   33.9       38.7        18           25
# 2   Compact       25.9   29.1       32.3        20           26
# 3   Midsize       30.8   37.7       44.6        19           26
# 4   Midsize       23.7   30.0       36.2        22           30
# ..      ...        ...    ...        ...       ...          ...
# 88      Van       16.6   19.7       22.7        17           21
# 89  Compact       17.6   20.0       22.4        21           30
# 90   Sporty       22.9   23.3       23.7        18           25
# 91  Compact       21.8   22.7       23.5        21           28
# 92  Midsize       24.8   26.7       28.5        20           28
#
#                AirBags DriveTrain Cylinders  EngineSize  ...  Passengers  \
# 0                 None      Front         4         1.8  ...           5
# ...

# %%
passengers=Car.sort_values(by=["Passengers"],ascending=False)

# %%
passengers
# Out:
#    Manufacturer     Model    Type  Min.Price  Price  Max.Price  MPG.city  \
# 16    Chevrolet     Astro     Van       14.7   16.6       18.6        15
# 25        Dodge   Caravan     Van       13.6   19.0       24.4        17
# 55        Mazda       MPV     Van       16.6   19.1       21.7        18
# 65       Nissan     Quest     Van       16.7   19.1       21.5        17
# 35         Ford  Aerostar     Van       14.5   19.9       25.3        15
# ..          ...       ...     ...        ...    ...        ...       ...
# 59      Mercury     Capri  Sporty       13.3   14.1       15.0        23
# 45      Hyundai    Scoupe  Sporty        9.1   10.0       11.0        26
# 72      Pontiac    LeMans   Small        8.2    9.0        9.9        31
# 18    Chevrolet  Corvette  Sporty       34.6   38.0       41.5        17
# 56        Mazda      RX-7  Sporty       32.5   32.5       32.5        17
#
#     MPG.highway      AirBags DriveTrain  ... Passengers  Length  Wheelbase  \
# ...

# %%
name=list(passengers.Make)[0:5]

# %%
no_of_people=list(passengers.Passengers)[0:5]

# %%
plt.figure(figsize=(8,8))
plt.bar(name,no_of_people)
plt.title("Passenger carrying capacity of top five companies")
plt.xlabel("Names")
plt.ylabel("Passenger")
plt.show()

# %%
weight=Car.sort_values(by="Weight",ascending=False).head()

# %%
weight
# Out:
#        Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 7     Large       22.6   23.7       24.9        16           25
# 65      Van       16.7   19.1       21.5        17           23
# 51    Large       34.4   36.1       37.8        18           26
# 16      Van       14.7   16.6       18.6        15           20
# 47  Midsize       45.4   47.9       50.4        17           22
#
#                AirBags DriveTrain Cylinders  EngineSize  ...  Passengers  \
# 7          Driver only       Rear         6         5.7  ...           6
# 65                None      Front         6         3.0  ...           7
# 51  Driver & Passenger       Rear         8         4.6  ...           6
# 16                None        4WD         6         4.3  ...           8
# 47         Driver only       Rear         8         4.5  ...           5
#
#     Length  Wheelbase Width  Turn.circle  Rear.seat.room  Luggage.room  \
# ...

# %%
name=list(weight.Make)

# %%
kg=list(weight.Weight)

# %%
plt.figure(figsize=(6,6))
plt.pie(kg,labels=name,autopct="%0.1ff%%",radius=2)
plt.pie([1],colors=["w"],radius=1)
plt.show()
